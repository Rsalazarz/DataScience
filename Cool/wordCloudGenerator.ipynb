# %%
# install wordcloud
# !conda install -c conda-forge wordcloud==1.4.1 --yes

# import package and its set of stopwords
from wordcloud import WordCloud, STOPWORDS

print ('Wordcloud is installed and imported!')
# Out:
# ...
# Solving environment: done
#
# # All requested packages already installed.
#
# Wordcloud is installed and imported!

# %%
# download file and save as alice_novel.txt
#!wget --quiet https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DV0101EN/labs/Data_Files/alice_novel.txt

# open the file and read it into a variable alice_novel
jazmintxt = open('untitled.txt', 'r').read()
    
print ('File downloaded and saved!')
stopwords = set(STOPWORDS)

jazmintxt_wc = WordCloud(
    background_color='white',
    max_words=2000,
    stopwords=stopwords
)

# generate the word cloud
jazmintxt_wc.generate(jazmintxt)

import matplotlib.pyplot as plt

plt.axis('off')
fig.set_figwidth(50) # set width
fig.set_figheight(18) # set height
plt.imshow(jazmintxt_wc, interpolation='bilinear')
plt.axis('off')
plt.show()
plt.show()
# Out:
# File downloaded and saved!

# %%
from PIL import Image # converting images into arrays
import numpy as np  # useful for many scientific computing in Python
jazmin_mask = np.array(Image.open('test.png'))
#jazmin_mask = np.array(Image.open('Png.png'))
fig = plt.figure()
fig.set_figwidth(14) # set width
fig.set_figheight(18) # set height

plt.imshow(jazmin_mask, cmap=plt.cm.gray, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
jazmin_wc = WordCloud(background_color='white', mask=jazmin_mask, stopwords=stopwords)

# generate the word cloud
jazmin_wc.generate(jazmintxt)

# display the word cloud
fig = plt.figure()
fig.set_figwidth(14) # set width
fig.set_figheight(18) # set height
plt.imshow(jazmin_wc, interpolation='bilinear')
plt.axis('off')
plt.show()
